# %%
import pandas as pd

array_of_interesting_nucldies_mother = [
    "cd106",
    "cd108",
    " kr78",
    " kr80",
    "ba130",
    "ba132",
    "er164",
    "xe124",
    "xe126",
    "sn112",
    "sn114",
    "ce136",
    " sr84",
    "te120"
]

dictionary = {
    "cd": 48,
    "kr": 36,
    "ba": 56,
    "er": 68,
    "xe": 54,
    "sn": 50,
    "ce": 58,
    "sr": 38,
    "te": 43
}

experimental_data = {
    "74|34": 0.580,
    "78|36": 0.146,
    "80|36": 0.940,
    "84|38": 0.128,
    "92|42": 0.634,
    "94|42": 0.361,
    "96|44": 0.105,
    "98|44": 0.036,
    "102|46": 0.013,
    "106|48": 0.019,
    "108|48": 0.014,
    "110|48": 0.020,
    "112|50": 0.036,
    "114|50": 0.024,
    "120|52": 5.8e-3,
    "124|54": 7.4e-3,
    "126|54": 6.7e-3,
    "130|56": 4.8e-3,
    "132|56": 4.7e-3,
    "136|58": 2.3e-3,
    "138|58": 3e-3,
    "144|62": 7.4e-3,
    "152|64": 8.4e-4,
    "156|66": 1.9e-4,
    "158|66": 3.3e-4,
    "162|68": 3.1e-4,
    "164|68": 3.6e-3,
    "168|70": 2.4e-4,
    "174|72": 3.1e-4,
    "180|74": 4e-4,
    "184|76": 1.2e-4,
    "190|78": 1.8e-4,
    "196|80": 3.1e-4
}

def compare_h5(fn1, fn2):
    def get_index(store, a, z):
        if (isinstance(store, pd.HDFStore)):
            sa = pd.Series(store.root.A)
            sz = pd.Series(store.root.Z)
            a_arr = sa[sa == a].keys()
            z_arr = sz[sz == z].keys()
            index = a_arr.intersection(z_arr)
            if (len(index) == 1):
                return index[0]
            else:
                raise "Not found element"
        else:
            raise "Error"

    store1 = pd.io.pytables.HDFStore(fn1)
    store2 = pd.io.pytables.HDFStore(fn2)
    f1 = open('out-abundancies/relative-real.txt', 'w')
    f2 = open('out-abundancies/relative-kr78.txt', 'w')
    
    for index in range(0, len(array_of_interesting_nucldies_mother)):
        item_for_compare = 'kr78'
        elem_name = array_of_interesting_nucldies_mother[index]
        z = dictionary[''.join(x for x in elem_name if x.isalpha())]        
        z_compare = dictionary[''.join(x for x in item_for_compare if x.isalpha())]
        a = int(''.join(x for x in elem_name if x.isdigit()))
        a_compare = int(''.join(x for x in item_for_compare if x.isdigit()))
        elem_index_for_compare = get_index(store1, a_compare, z_compare)
        elem_index = get_index(store1, a, z)
        size_t1, _ = store1.root.Y.shape
        y1 = store1.root.Y[size_t1 - 1][elem_index]
        y1_for_compare = store1.root.Y[size_t1 - 1][elem_index_for_compare]
        none = 'None'
        ex_y = experimental_data.get('{0}|{1}'.format(a, z), 0)
        ex_y_for_compare = experimental_data['{0}|{1}'.format(a_compare, z_compare)]
        #print('y1: ' + str(y1))
        print('y1_for_compare: ' + str(y1_for_compare))
        print('ex_y_for_compare: ' + str(ex_y_for_compare))
        #print('ex_y: ' + str(ex_y))
        size_t2, _ = store2.root.Y.shape
        y2 = store2.root.Y[size_t2 - 1][elem_index]
        print("{0} {1} {2}".format(elem_name, y1, y2),
             file=f1)
        print("{0} {1} {2}".format(elem_name, y1/y1_for_compare, ex_y/ex_y_for_compare),
             file=f2)
    store1.close()
    store2.close()
    f1.close()
    f2.close()

folder_name = 'out-r'
for index in range(1, 2):
    compare_h5(folder_name + '/WithMy-' + str(index) + '.h5', 
        folder_name + '/WithoutMy-' + str(index) + '.h5')
# Out:
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146
# y1_for_compare: 4.2705805262321004e-99
# ex_y_for_compare: 0.146

# %%
import pandas as pd

array_of_interesting_nucldies_mother = [
    "cd106",
    "cd108",
    " kr78",
    " kr80",
    "ba130",
    "ba132",
    "er164",
    "xe124",
    "xe126",
    "sn112",
    "sn114",
    "ce136",
    " sr84",
    "te120",
    " se74",
    "hf136"
]

dictionary = {
    "cd": 48,
    "kr": 36,
    "ba": 56,
    "er": 68,
    "xe": 54,
    "sn": 50,
    "ce": 58,
    "sr": 38,
    "te": 43,
    "se": 34,
    "hf": 72
}

experimental_data = {
    "74|34": 0.580,
    "78|36": 0.146,
    "80|36": 0.940,
    "84|38": 0.128,
    "92|42": 0.634,
    "94|42": 0.361,
    "96|44": 0.105,
    "98|44": 0.036,
    "102|46": 0.013,
    "106|48": 0.019,
    "108|48": 0.014,
    "110|48": 0.020,
    "112|50": 0.036,
    "114|50": 0.024,
    "120|52": 5.8e-3,
    "124|54": 7.4e-3,
    "126|54": 6.7e-3,
    "130|56": 4.8e-3,
    "132|56": 4.7e-3,
    "136|58": 2.3e-3,
    "138|58": 3e-3,
    "144|62": 7.4e-3,
    "152|64": 8.4e-4,
    "156|66": 1.9e-4,
    "158|66": 3.3e-4,
    "162|68": 3.1e-4,
    "164|68": 3.6e-3,
    "168|70": 2.4e-4,
    "174|72": 3.1e-4,
    "180|74": 4e-4,
    "184|76": 1.2e-4,
    "190|78": 1.8e-4,
    "196|80": 3.1e-4
}

def compare_h5(fn1, fn2):
    def get_index(store, a, z):
        if (isinstance(store, pd.HDFStore)):
            sa = pd.Series(store.root.A)
            sz = pd.Series(store.root.Z)
            a_arr = sa[sa == a].keys()
            z_arr = sz[sz == z].keys()
            index = a_arr.intersection(z_arr)
            if (len(index) == 1):
                return index[0]
            else:
                print("Element not found, A = {0}, Z={1}".
                               format(a, z))
                return -1
        else:
            raise "Error"

    store1 = pd.io.pytables.HDFStore(fn1)
    store2 = pd.io.pytables.HDFStore(fn2)
    
    for index in range(0, len(array_of_interesting_nucldies_mother)):
        # item_for_compare = 'kr78'
        elem_name = array_of_interesting_nucldies_mother[index]
        z = dictionary[''.join(x for x in elem_name if x.isalpha())]        
        # z_compare = dictionary[''.join(x for x in item_for_compare if x.isalpha())]
        a = int(''.join(x for x in elem_name if x.isdigit()))
        # a_compare = int(''.join(x for x in item_for_compare if x.isdigit()))
        elem_index = get_index(store1, a, z)
        if (elem_index == -1):
            continue
        size_t1, _ = store1.root.Y.shape
        y1 = store1.root.Y[size_t1 - 1][elem_index]
        size_t2, _ = store2.root.Y.shape
        y2 = store2.root.Y[size_t2 - 1][elem_index]
        print("{0}, WithMy: {1}, WithoutMy: {2}".format(elem_name, y1, y2))
    store1.close()
    store2.close()

folder_name = 'out-r'
for index in range(1, 2):
    compare_h5(folder_name + '/WithMy-' + str(index) + '.h5', 
        folder_name + '/WithoutMy-' + str(index) + '.h5')
# Out:
# cd106, WithMy: 4.393405151003657e-113, WithoutMy: 7.113582140263191e-112
# cd108, WithMy: 1.3545632752150976e-22, WithoutMy: 2.683598087952687e-22
#  kr78, WithMy: 4.2705805262321004e-99, WithoutMy: 3.1221049711923076e-99
#  kr80, WithMy: 1.3328232991044714e-22, WithoutMy: 2.2277054667892732e-25
# ba130, WithMy: 2.034058891428071e-136, WithoutMy: 1.1985268428213709e-133
# ba132, WithMy: 6.962811786408774e-141, WithoutMy: 9.409257765643968e-139
# er164, WithMy: 0.0, WithoutMy: 0.0
# xe124, WithMy: 1.2879451493702548e-130, WithoutMy: 2.0524824952415844e-128
# xe126, WithMy: 6.450807504829386e-123, WithoutMy: 2.2219741994388188e-122
# sn112, WithMy: 1.3141332764311816e-114, WithoutMy: 3.7961301854405106e-113
# sn114, WithMy: 2.6227162260770796e-32, WithoutMy: 2.6944859964998246e-32
# ce136, WithMy: 3.716626246239773e-145, WithoutMy: 4.518651926213627e-143
#  sr84, WithMy: 2.231020015248196e-95, WithoutMy: 6.12058893417101e-94
# te120, WithMy: 3.654729584250905e-234, WithoutMy: 1.7224459055600713e-214
#  se74, WithMy: 3.2858112683753846e-90, WithoutMy: 2.583136373155023e-91
# Element not found, A = 136, Z=72
